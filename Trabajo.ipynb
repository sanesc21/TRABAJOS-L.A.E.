# %% [markdown]
# |                |   |
# :----------------|---|
# | **Nombre**     |Santiago Escutia Ríos   |
# | **Fecha**      | 3/2/2026  |
# | **Expediente** |  757839 |

# %%
import pandas as pd
df=pd.read_excel("Boston Housing Dataset 1978.xlsx")

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
import pandas as pd
import numpy as np

Scales = pd.DataFrame()
Scales["Periodo"] = np.array([
    "ZN","INDUS","CHAS","NOX","RM","AGE",
    "DIS","RAD","TAX","PTRATIO","B","LSTAT"
])

Datasetescalable = pd.DataFrame()

for column in Scales["Periodo"]:
    Datasetescalable[column + "_escalable"] = (
        (df[column] - df[column].min()) /
        (df[column].max() - df[column].min())
    )

# %%
Datasetescalable.describe()
# Out:
#        ZN_escalable  INDUS_escalable  CHAS_escalable  NOX_escalable  \
# count    506.000000       506.000000      506.000000     506.000000
# mean       0.132953         0.331837        0.140765       0.103374
# std        0.230487         0.258458        0.312765       0.237730
# min        0.000000         0.000000        0.000000       0.000000
# 25%        0.000000         0.124009        0.000000       0.009238
# 50%        0.000000         0.250901        0.000000       0.022084
# 75%        0.181000         0.652487        0.000000       0.037818
# max        1.000000         1.000000        1.000000       1.000000
#
#        RM_escalable  AGE_escalable  DIS_escalable  RAD_escalable  \
# count    506.000000     506.000000     506.000000     506.000000
# mean       0.125663       0.582702       0.220534       0.115885
# std        0.282253       0.334848       0.283180       0.306078
# min        0.000000       0.000000       0.000000       0.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler
Scaler= StandardScaler()
for i in Escalas ["Variables"]
    Da

# %%
df.hist()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 df.hist()
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

Datasetescalable.hist(figsize=(12,8), bins=20)
plt.tight_layout()
plt.show()
